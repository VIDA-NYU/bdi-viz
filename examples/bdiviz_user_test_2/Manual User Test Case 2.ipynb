# %% [markdown]
# # BDIViz User Test Case 2

# %% [markdown]
# ## Supplimentary Material
#
# ---
#
# #### Paper info:
#
# _Dou et al._
#
#
# We characterized a prospective endometrial carcinoma (EC) cohort containing 138 tumors and 20 enriched normal tissues using 10 different omics platforms. Targeted quantitation of two peptides can predict antigen processing and presentation machinery activity, and may inform patient selection for immunotherapy. Association analysis between MYC activity and metformin treatment in both patients and cell lines suggests a potential role for metformin treatment in non-diabetic patients with elevated MYC activity. PIK3R1 in-frame indels are associated with elevated AKT phosphorylation and increased sensitivity to AKT inhibitors. CTNNB1 hotspot mutations are concentrated near phosphorylation sites mediating pS45-induced degradation of β-catenin, which may render Wnt-FZD antagonists ineffective. Deep learning accurately predicts EC subtypes and mutations from histopathology images, which may be useful for rapid diagnosis. Overall, this study identified molecular and imaging markers that can be further investigated to guide patient stratification for more precise treatment of EC.
#
# - [**Dou, et al: CPTAC Discovery**](https://pubmed.ncbi.nlm.nih.gov/32059776/)
#
# - [**Dou, et al: CPTAC Confirmatory**](https://pubmed.ncbi.nlm.nih.gov/37567170/)

# %% [markdown]
# ## 0. Load Dataset

# %%
import pandas as pd
import numpy as np

import panel as pn

# %%
# Dou sample #1
source = pd.read_csv("Dou-ucec-sample-1.csv").drop(columns=["Unnamed: 0"])

target = pd.read_csv("Dou-ucec-confirmatory.csv")

# %%
source
# Out:
#        BMI               Ethnicity Proteomics_Tumor_Normal  \
# 0    38.88  Not-Hispanic or Latino                   Tumor
# 1    39.76  Not-Hispanic or Latino                   Tumor
# 2    51.19  Not-Hispanic or Latino                   Tumor
# 3      NaN                     NaN                   Tumor
# 4    32.69  Not-Hispanic or Latino                   Tumor
# ..     ...                     ...                     ...
# 148    NaN                     NaN         Enriched_normal
# 149    NaN                     NaN         Enriched_normal
# 150    NaN                     NaN         Enriched_normal
# 151    NaN                     NaN         Enriched_normal
# 152    NaN                     NaN         Enriched_normal
#
#         Estrogen_Receptor                        PMS2  \
# 0    Cannot be determined   Intact nuclear expression
# 1    Cannot be determined  Loss of nuclear expression
# 2    Cannot be determined   Intact nuclear expression
# 3                     NaN                         NaN
# 4    Cannot be determined   Intact nuclear expression
# ..                    ...                         ...
# 148                   NaN                         NaN
# 149                   NaN                         NaN
# 150                   NaN                         NaN
# 151                   NaN                         NaN
# 152                   NaN                         NaN
#
#      CIBERSORT_Mast _cells _activated Genomics_subtype  ESTIMATE_StromalScore  \
# 0                            0.000000            MSI-H            2821.088429
# 1                            0.015087            MSI-H            2714.248104
# 2                            0.033825          CNV_low            3856.501277
# 3                                 NaN              NaN                    NaN
# 4                            0.000000          CNV_low            3012.556593
# ..                                ...              ...                    ...
# 148                               NaN              NaN                    NaN
# 149                               NaN              NaN                    NaN
# 150                               NaN              NaN                    NaN
# 151                               NaN              NaN                    NaN
# 152                               NaN              NaN                    NaN
#
#     Clin_Stage_Dist_Mets-cM                       Path_Stage_Dist_Mets-pM
# 0                       cM0                            Staging Incomplete
# 1                       cM0                            Staging Incomplete
# 2                       cM0                            Staging Incomplete
# 3                       NaN                                           NaN
# 4                       cM0  No pathologic evidence of distant metastasis
# ..                      ...                                           ...
# 148                     NaN                                           NaN
# 149                     NaN                                           NaN
# 150                     NaN                                           NaN
# 151                     NaN                                           NaN
# 152                     NaN                                           NaN
#
# [153 rows x 10 columns]

# %%
target
# Out:
#      Unnamed: 0        Idx    Case_id Case_excluded Batch  Plex ReporterName  \
# 0             0  C3L-00086  C3L-00086            No    b4  16.0         128N
# 1             1  C3L-00898  C3L-00898            No    b4  14.0         128C
# 2             2  C3L-00943  C3L-00943            No    b4  15.0         130C
# 3             3  C3L-01064  C3L-01064            No    b3   9.0         129N
# 4             4  C3L-01277  C3L-01277            No    b4  13.0         130N
# ..          ...        ...        ...           ...   ...   ...          ...
# 185         185      NX034      NX034            No    b1   4.0         129N
# 186         186      NX035      NX035            No    b1   3.0         129C
# 187         187      NX036      NX036            No    b2   7.0         129N
# 188         188      NX037      NX037            No    b4  16.0         130C
# 189         189      NX038      NX038            No    b2   6.0         131C
#
#         Aliquot_ID            Group Discovery_study  ...  \
# 0    CPT0092460003            Tumor              No  ...
# 1    CPT0172200008            Tumor              No  ...
# 2    CPT0086090003            Tumor              No  ...
# 3    CPT0113430004            Tumor              No  ...
# 4    CPT0093170003            Tumor              No  ...
# ..             ...              ...             ...  ...
# 185  CPT0313400002  Enriched_Normal             NaN  ...
# 186  CPT0313420003  Enriched_Normal             NaN  ...
# 187  CPT0313490002  Enriched_Normal             NaN  ...
# 188  CPT0313420007  Enriched_Normal             NaN  ...
# 189  CPT0313420004  Enriched_Normal             NaN  ...
#
#     Follow-up_additional_surgery_for_new_tumor  \
# 0                              n/a|No|No|No|No
# 1                              n/a|n/a|n/a|n/a
# 2                                  n/a|n/a|n/a
# 3                                  No|No|No|No
# 4                                    n/a|No|No
# ..                                         ...
# 185                                        NaN
# 186                                        NaN
# 187                                        NaN
# 188                                        NaN
# 189                                        NaN
#
#     Follow-up_additional_treatment_radiation_therapy_for_new_tumor  \
# 0                                  n/a|Yes|Yes|Yes|Yes
# 1                                      n/a|n/a|n/a|n/a
# 2                                          n/a|n/a|n/a
# 3                                         No|Yes|No|No
# 4                                           n/a|No|Yes
# ..                                                 ...
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
#
#     Follow-up_additional_treatment_pharmaceutical_therapy_for_new_tumor  \
# 0                                  n/a|Yes|Yes|Yes|Yes
# 1                                      n/a|n/a|n/a|n/a
# 2                                          n/a|n/a|n/a
# 3                                      Yes|Yes|Yes|Yes
# 4                                           n/a|Yes|No
# ..                                                 ...
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
#
#     Follow-up_additional_treatment_immuno_for_new_tumor  \
# 0                                      n/a|No|No|No|No
# 1                                      n/a|n/a|n/a|n/a
# 2                                          n/a|n/a|n/a
# 3                                          No|No|No|No
# 4                                            n/a|No|No
# ..                                                 ...
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
#
#      Follow-up_days_from_date_of_collection_to_date_of_last_contact  \
# 0                        330.0|701.0|1046.0|1436.0|n/a
# 1                             396.0|746.0|982.0|1600.0
# 2                                   237.0|693.0|1039.0
# 3                            453.0|726.0|1062.0|1447.0
# 4                                    351.0|713.0|967.0
# ..                                                 ...
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
#
#              Follow-up_cause_of_death  \
# 0    n/a|n/a|n/a|n/a|Breast Carcinoma
# 1                     n/a|n/a|n/a|n/a
# 2                         n/a|n/a|n/a
# 3                     n/a|n/a|n/a|n/a
# 4                         n/a|n/a|n/a
# ..                                ...
# 185                               NaN
# 186                               NaN
# 187                               NaN
# 188                               NaN
# 189                               NaN
#
#      Follow-up_days_from_date_of_initial_pathologic_diagnosis_to_date_of_death  \
# 0                               n/a|n/a|n/a|n/a|1578.0
# 1                                      n/a|n/a|n/a|n/a
# 2                                          n/a|n/a|n/a
# 3                                      n/a|n/a|n/a|n/a
# 4                                          n/a|n/a|n/a
# ..                                                 ...
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
#
#      Follow-up_days_from_date_of_initial_pathologic_diagnosis_to_date_of_additional_surgery_for_new_tumor  \
# 0                                  n/a|n/a|n/a|n/a|n/a
# 1                                      n/a|n/a|n/a|n/a
# 2                                          n/a|n/a|n/a
# 3                                      n/a|n/a|n/a|n/a
# 4                                          n/a|n/a|n/a
# ..                                                 ...
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
#
#     Follow-up_procedure_type_of_new_tumor  \
# 0                     n/a|n/a|n/a|n/a|n/a
# 1                         n/a|n/a|n/a|n/a
# 2                             n/a|n/a|n/a
# 3                         n/a|n/a|n/a|n/a
# 4                             n/a|n/a|n/a
# ..                                    ...
# 185                                   NaN
# 186                                   NaN
# 187                                   NaN
# 188                                   NaN
# 189                                   NaN
#
#     Follow-up_residual_tumor_after_surgery_for_new_tumor
# 0                                  n/a|n/a|n/a|n/a|n/a
# 1                                      n/a|n/a|n/a|n/a
# 2                                          n/a|n/a|n/a
# 3                                      n/a|n/a|n/a|n/a
# 4                                          n/a|n/a|n/a
# ..                                                 ...
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
#
# [190 rows x 214 columns]
